# %%
import os
import requests
import pandas as pd

# 👇 Set working directory
os.chdir(r"[MY WORKING DIRECTORY HERE]")

# Input / output files
input_file = "[MY INPUT FILE HERE].xlsx"  # Replace with your actual input file name
output_file = "[MY OUTPUT FILE NAME HERE].xlsx" # Replace with your desired output file name

# Load Excel
df = pd.read_excel(input_file)

# Prepare results list
results = []

# Your OCLC Access Token (replace with real one)
OCLC_TOKEN = "[MY OCLC TOKEN HERE]"  # Replace with your actual OCLC token

# Iterate over each row in the Excel
for idx, row in df.iterrows():
    title = str(row["ti:"]).strip() if not pd.isna(row["ti:"]) else ""  #the header for title column should be "ti:"
    author = str(row["au:"]).strip() if not pd.isna(row["au:"]) else "" #the header for author column should be "au:"

    if not title:
        continue  # skip empty rows

    # Build query 
    query = f'ti:"{title}"'
    if author:
        query += f' AND au:"{author}"'

    url = "https://americas.discovery.api.oclc.org/worldcat/search/v2/bibs"
    token = "[MY OCLC TOKEN HERE]"
    params = {
        "q": query,
        "inLanguage": "eng",   #add parameter to limit to English results
        "inCatalogLanguage": "eng", #add parameter to limit to English catalog records
        "itemType": "video", #add parameter to limit to video items
        "limit": 1  # we only need the first result
    }
    headers = {
        "Accept": "application/json",
        "Authorization": f'Bearer {token}'
    }

    try:
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()

        if data.get("numberOfRecords", 0) > 0:
            record = data["bibRecords"][0]
            oclc_num = record["identifier"].get("oclcNumber", "")
            main_titles = "; ".join([t["text"] for t in record["title"].get("mainTitles", [])])
        else:
            oclc_num = ""
            main_titles = ""

        results.append({
            "Local_Title": title, #save original title in case of no match
            "Local_Author": author, #save original author in case of no match
            "OCLC_Number": oclc_num, #save OCLC number if found
            "OCLC_Title": main_titles #save OCLC title if found
        })

        print(f"✔ {title} → {oclc_num}")

    except Exception as e:
        print(f"❌ Error for {title}: {e}")
        results.append({
            "Local_Title": title,
            "Local_Author": author,
            "OCLC_Number": "",
            "OCLC_Title": ""
        })

# Save results to Excel
out_df = pd.DataFrame(results)
out_df.to_excel(output_file, index=False)

print(f"\n✅ Finished! Results saved to {os.path.join(os.getcwd(), output_file)}")
# Out:
# ✔ The flash → 62785429
# ✔ Barbarosa → 52742524
# ✔ Grand avenue → 29594563
# ✔ Army of darkness → 436317340
# ✔ Chaplin → 732809208
# ✔ Scenes from a mall → 156277740
# ✔ Clean slate → 51522619
# ✔ Bill and ted's bogus journey → 1058602941
# ✔ Taking liberty →
# ✔ On deadly ground → 44896836
# ✔ What about bob? → 44846342
# ✔ Ambush → 30011771
# ✔ Lonestar → 55506425
# ✔ True grit → 123960543
# ✔ True grit → 123960543
# ✔ Copycat → 1193470085
# ✔ The remains of the day → 222096317
# ✔ Afterlife → 262295549
# ✔ Before i wake →
# ✔ Gremlins 2 → 50411105
# ✔ Benny and joon → 302327381
# ✔ Get shorty →
# ✔ m word, the →
# ✔ The golden touch → 331972
# ✔ School ties → 44225152
# ✔ Crackers → 723247081
# ✔ Eight million ways to die → 987004638
# ✔ Austin powers → 1001494513
# ✔ A stranger among us → 156275152
# ✔ Sleepers → 38062196
# ✔ Bad boys ii →
# ✔ Con air → 44991840
# ✔ Devil's own → 39511837
# ✔ Star trek → 31491225
# ✔ The peacemaker → 40558736
# ✔ Dante's peak → 40384822
# ✔ Starship troopers → 39183348
# ✔ The game → 51460434
# ✔ Freddy vs jason → 660851283
# ✔ Face off → 40699961
# ✔ Mars attacks → 40073183
# ✔ Excess baggage → 71685703
# ✔ Independent, the → 1505977849
# ✔ Scythe → 1323246979
# ✔ Mission → 67246991
# ✔ Eaters of the dead → 1959473
# ✔ Copland → 1190935064
# ✔ Men in black → 232161496
# ✔ Jerry maguire → 39609600
# ✔ Strange days → 42877325
# ✔ Wayne's world 2 → 47056740
# ✔ Swimming with sharks → 192011910
# ✔ I'll do anything → 156276073
# ✔ Naked in new york → 56628732
# ✔ Nothing to lose → 43317069
# ✔ Lone star → 43186091
# ✔ The first wives club → 44880118
# ✔ Higher learning → 47688979
# ✔ Cemetery club, the →
# ✔ Bottle rocket → 261598934
# ✔ Angus → 503006606
# ✔ The beautician and the beast → 52060775
# ✔ The trigger effect → 42712547
# ✔ Heavy → 53314929
# ✔ I shot andy warhol → 34651526
# ✔ Alien → 53816173
# ✔ Smoke and mirrors → 228151187
# ✔ Citizen x → 45536183
# ✔ Running scared → 49422127
# ✔ Cobb → 53193535
# ✔ Cool hand luke → 244838223
# ✔ Dark city → 234091034
# ✔ Doctor zhivago → 48379860
# ✔ Rape of richard mills, the →
# ✔ Legal eagles → 52073832
# ✔ Independence day → 34633472
# ✔ Foul play → 56909068
# ✔ Greencard → 40654082
# ✔ Lethal weapon 4 → 44629621
# ✔ Assassins → 40093208
# ✔ Last dance → 52219033
# ✔ Showgirls → 44488250
# ✔ Net, the → 222973571
# ✔ Under siege 2 → 43643522
# ✔ Mallrats → 42399419
# ✔ Home for the holidays → 47890494
# ✔ Twelve monkeys → 39102879
# ✔ White squall → 42384861
# ✔ Canadian bacon → 48228860
# ✔ Twenty thousand leagues under the sea → 18900452
# ✔ The fatal shore →
# ✔ Honeymoon in vegas → 44550903
# ✔ Flipper → 54086184
# ✔ The english patient → 55881775
# ✔ Frog → 46802643
# ✔ Party of five → 54979037
# ✔ Angie → 53942046
# ✔ Men of respect →
# ✔ Penn & teller get killed → 550641003
# ✔ Hear my song → 856118168
# ✔ Family plot → 62893228
# ✔ Immortal beloved → 51907737
# ✔ Miami rhapsody → 43802107
# ✔ Memoirs of an invisible man → 906596023
# ✔ Marnie → 62893244
# ✔ Darkman → 41439439
# ✔ Killer → 166331401
# ✔ Mogambo → 68815729
# ✔ I confess → 156284994
# ✔ The 'burbs → 42403643
# ✔ A little princess → 35243342
# ✔ Dream lover → 156277072
# ✔ Storyville → 53444970
# ✔ Wild at heart → 57180699
# ✔ The mirror has two faces → 61728436
# ✔ All the pretty horses → 46854985
# ✔ Treasure of the sierra madre, the → 919313983
# ✔ Gleaming the cube → 156276167
# ✔ The little mermaid → 65519794
# ✔ Tin men → 49529137
# ✔ The border → 55232631
# ✔ Buffy, the vampire slayer → 1015828202
# ✔ No man's land → 51978234
# ✔ Duke and boots →
# ✔ Seven → 41504736
# ✔ Truth about cats and dogs, the →
# ✔ The other side of the mountain part ii → 122383331
# ✔ The heiress → 1713288
# ✔ Back to school → 26249572
# ✔ Madeleine →
# ✔ The favor → 48999354
# ✔ The getaway → 60767941
# ✔ Flight of the intruder → 52061095
# ✔ Charade → 54928227
# ✔ Blow-out → 712067582
# ✔ The field → 50297457
# ✔ Big wednesday → 50244891
# ✔ Great gatsby, the →
# ✔ Gilda → 45296800
# ✔ Marriage is a private affair →
# ✔ Russia house, the →
# ✔ Heat → 11468141
# ✔ The godfather →
# ✔ Better off dead → 50238602
# ✔ This is spinal tap → 425958477
# ✔ The last emperor → 261599898
# ✔ Anatomy of a murder → 44707513
# ✔ The jerk → 60696545
# ✔ Fire down below → 40742661
# ✔ Mad love → 43575585
# ✔ Incredible shrinking man, the →
# ✔ Blowhard! →
# ✔ Man called sarge, a →
# ✔ Wide sargasso sea → 24630204
# ✔ Play it again sam → 7290883
# ✔ What makes sammy run? → 287618
# ✔ Father of the bride → 41494911
# ✔ While you were sleeping → 40066712
# ✔ Blank check → 51829924
# ✔ Navy seals → 45994303
# ✔ Predator 2 → 51636092
# ✔ Poltergeist → 172896016
# ✔ Breakin' 2 → 52060830
# ✔ Arachnophobia → 42414696
# ✔ Lost in america → 47703682
# ✔ Paradise → 56532727
# ✔ Nashville → 51570636
# ✔ Gi joe →
# ✔ Tremors → 1344013520
# ✔ Sheltering sky, the →
# ✔ She's delovely → 801274110
# ✔ The lies boys tell → 550683681
# ✔ Three men and a little lady → 49780661
# ✔ Mirage → 712795735
# ✔ Just cause → 44740155
# ✔ The thin man → 61137339
# ✔ Counterfeit contessa, the →
# ✔ Last boy scout, the → 608126532
# ✔ Batman returns → 25872647
# ✔ Raging bull → 57206235
# ✔ Back to the future ii → 299176212
# ✔ Alien nation → 46655563
# ✔ Barfly → 50550536
# ✔ Shampoo → 51522941
# ✔ The killing time → 74496335
# ✔ Rage in harlem, a →
# ✔ Stage fright → 56365704
# ✔ From here to eternity → 48241052
# ✔ Atlantic city → 49884103
# ✔ The phantom of the opera → 370361220
# ✔ Reservoir dogs → 43286885
# ✔ The phantom of the opera → 156279708
# ✔ Fisher king, the → 1102089740
# ✔ Interview with the vampire → 614521648
# ✔ Chinatown → 42581549
# ✔ Dumb and dumber → 899218504
# ✔ Back to the future → 297618476
# ✔ Carnal knowledge → 241443
# ✔ Eight men out → 47248593
# ✔ The bridge on the river kwai → 1083051898
# ✔ Mr saturday night → 50046986
# ✔ Major league → 95221445
# ✔ Big → 30892644
# ✔ Last action hero → 40222719
# ✔ Program, the → 50253280
# ✔ The monster squad → 133653573
# ✔ Simple twist of fate, a →
# ✔ Outbreak → 41112837
# ✔ Shadow of a doubt → 62869228
# ✔ Judge dredd → 46644286
# ✔ The breakfast club → 234573242
# ✔ The godfather ii → 1019732687
# ✔ Alien iii     bound →
# ✔ On the waterfront → 48239414
# ✔ Alien iii   bound →
# ✔ Alien III → 25465041
# ✔ Crow, the → 65429353
# ✔ Dave → 39850195
# ✔ Dominick and eugene → 48684220
# ✔ Until the end of the world → 25314495
# ✔ On golden pond → 4933842
# ✔ Smokey and the bandit → 67839527
# ✔ Breakfast at tiffany's → 45283744
# ✔ The wind and the lion → 54025806
# ✔ Big chill, the → 1325716473
# ✔ Five corners → 698130285
# ✔ His girl friday → 57139690
# ✔ The graduate → 59107623
# ✔ In the heat of the night → 45860183
# ✔ All about eve → 51501378
# ✔ 48 → 40797330
# ✔ He said, she said → 48509122
# ✔ Paper moon → 52851152
# ✔ Mccabe and mrs miller → 892185145
# ✔ Zorba →
# ✔ The nightmare before christmas → 1040698292
# ✔ Diner → 43864112
# ✔ Reality bites → 55987955
# ✔ To sleep with anger → 1082146831
# ✔ Searching for bobby fischer → 50332089
# ✔ The stunt man → 729391592
# ✔ Continental divide → 52114297
# ✔ Return of the jedi → 9553385
# ✔ Maltese falcon, the → 1460296659
# ✔ The age of innocence → 1082497642
# ✔ The accidental tourist → 54012480
# ✔ For whom the bell tolls → 41214097
# ✔ Free jack → 317408973
# ✔ Total recall → 50903896
# ✔ Aladdin → 55539399
# ✔ Psycho → 39191933
# ✔ Singin' in the rain → 379187
# ✔ Fletch lives → 52998958
# ✔ The untouchables → 55859331
# ✔ Three fugitives → 49845169
# ✔ The lawnmower man → 40223036
# ✔ Dirty rotten scoundrels → 48983082
# ✔ I wanna hold your hand → 1085364369
# ✔ The rocky horror picture show → 50500515
# ✔ Bugsy → 76823654
# ✔ The front page → 60412957
# ✔ Eight seconds → 38163163
# ✔ Cape fear →
# ✔ Favorite son → 15589383
# ✔ Man in the iron mask, the →
# ✔ Monty python's life of brian → 173221556
# ✔ A dry white season → 62149985
# ✔ Marathon man → 940709
# ✔ Sleeping with the enemy → 53062416
# ✔ Once upon a time in america → 11770261
# ✔ Once upon a time in america → 11770261
# ✔ Jake and the fatman - "aloha" →
# ✔ Not of this earth ii →
# ✔ Dune → 10726946
# ✔ Raiders of the lost ark → 7323170
# ✔ Bill and ted's excellent adventure → 35906630
# ✔ Blue steel → 51254424
# ✔ A nightmare on elm street iii - dream warriors → 801221506
# ✔ The accused → 222714653
# ✔ Red heat → 56452006
# ✔ Mr and mrs bridge → 25619403
# ✔ La takedown → 1085891257
# ✔ In the name of the father → 40122566
# ✔ The beans of egypt, maine → 801204437
# ✔ Stand by me → 45105146
# ✔ Rear window → 46397587
# ✔ Real genius → 50048376
# ✔ Double impact → 47256408
# ✔ Days of thunder → 42414496
# ✔ Prophecy, the → 852710772
# ✔ The couch trip → 52272029
# ✔ Fight for life →
# ✔ Shadow company →
# ✔ Conversation, the →
# ✔ Git gat gone →
# ✔ Rope → 71222812
# ✔ Empire strikes back, the → 42629887
# ✔ Notorious → 259718874
# ✔ Greystoke → 17542455
# ✔ White men can't jump → 45129598
# ✔ Deep cover → 1251391390
# ✔ Frasier → 54085468
# ✔ Legend of zorro, the →
# ✔ The killers → 927963120
# ✔ Twelve angry men → 65521642
# ✔ Lethal weapon 3 → 44629621
# ✔ Agnes of god → 9114583
# ✔ Weird science → 236106724
# ✔ Convicts → 793384989
# ✔ House party → 44559638
# ✔ Blood will tell → 55499716
# ✔ Coal miner's daughter → 61315722
# ✔ Heathers → 48151265
# ✔ Lucas → 51948611
# ✔ To kill a mockingbird → 39021174
# ✔ Twin peaks → 982965223
# ✔ Terms of endearment → 46852006
# ✔ Crimson tide → 40462807
# ✔ Dr strangelove → 225490267
# ✔ The last temptation of christ → 44018570
# ✔ Shadow, the →
# ✔ The eiger sanction → 43084025
# ✔ Jaws → 793612
# ✔ Tootsie → 185036879
# ✔ Star trek → 31491225
# ✔ When a man loves a woman → 44602232
# ✔ Bert rigby, you're a fool! → 689154451
# ✔ War of the worlds - "the resurrection" →
# ✔ Village of the damned → 40658414
# ✔ Children of a lesser god → 45672253
# ✔ Quiz show → 42690654
# ✔ Midnight cowboy → 39481827
# ✔ An american werewolf in london → 48021259
# ✔ Glory → 166345319
# ✔ Ordinary people → 47780088
# ✔ Batman → 19712581
# ✔ Rio bravo → 46926230
# ✔ Where the day takes you → 825069768
# ✔ A few good men → 26132261
# ✔ Angel heart → 55507387
# ✔ Poetic justice → 42399357
# ✔ Beaches → 58837355
# ✔ Murder, my sweet → 55733900
# ✔ F/x → 45066862
# ✔ Sting, the → 809762887
# ✔ Ruthless people → 49546007
# ✔ Silkwood → 53131505
# ✔ The mission → 52283425
# ✔ Glengarry glen ross → 10429968
# ✔ The road warrior → 37550551
# ✔ The larry sanders show → 423102859
# ✔ Mikey and nicky → 1077754290
# ✔ All of me → 45373269
# ✔ City slickers → 46995701
# ✔ Halloween → 1077022615
# ✔ La story → 59388878
# ✔ Birdy → 43922921
# ✔ To live and die in LA → 549522660
# ✔ See no evil, hear no evil →
# ✔ The package → 44754504
# ✔ Love and death → 44570040
# ✔ Unfaithfully yours → 60565622
# ✔ Camp nowhere → 52916419
# ✔ Young frankenstein → 68569822
# ✔ Murder by death → 190692013
# ✔ Suspicion → 56493609
# ✔ Dark wind, the →
# ✔ Little man tate → 47977357
# ✔ Halloween 4 → 70847822
# ✔ What's love got to do with it? → 44749986
# ✔ Alive → 853017925
# ✔ Cheese stands alone, the →
# ✔ The getaway → 60767941
# ✔ Falling down → 42859497
# ✔ The babysitter → 913797104
# ✔ Ballad of little jo, the →
# ✔ Casualties of war → 48918995
# ✔ Platoon → 732723416
# ✔ First knight →
# ✔ Carlito's way → 53033524
# ✔ The godfather part iii → 48143991
# ✔ Kingpin → 42018503
# ✔ Roxanne → 40757679
# ✔ Human comedy, the →
# ✔ Magnum force → 228443595
# ✔ Magnum force → 228443595
# ✔ Something wild → 714160280
# ✔ City of hope → 298183986
# ✔ Pat and mike → 45702436
# ✔ Roman holiday → 51226517
# ✔ Naked tango → 26766634
# ✔ Colors → 48502519
# ✔ Fatal attraction → 49233077
# ✔ Kalifornia → 47918012
# ✔ Player, the → 29754332
# ✔ Ironweed → 8709244
# ✔ About last night → 876080616
# ✔ Unhook the stars → 55996599
# ✔ Moon over parador → 57375331
# ✔ Informer, the →
# ✔ Ladyhawke → 44579000
# ✔ Toys → 48747802
# ✔ Rat race →
# ✔ Westworld → 1054004433
# ✔ Mildred pierce → 6420595
# ✔ Mr horn → 4913057
# ✔ Driving miss daisy → 18381082
# ✔ An early frost → 70280754
# ✔ Sea kings, the →
# ✔ The habitation of dragons → 29202264
# ✔ The heavenly kid → 62208247
# ✔ Cold feet → 56977160
# ✔ Dead, the → 414846845
# ✔ Chances are → 45448153
# ✔ Fat man and little boy → 54315353
# ✔ The lemon sisters → 46761618
# ✔ Forever mine → 47003919
# ✔ Torch song trilogy → 9646514
# ✔ Breaking in → 49659681
# ✔ Nostromo → 271759137
# ✔ I'm gonna git you sucka! → 45808742
# ✔ How to marry a millionaire →
# ✔ A night in the life of jimmy reardon → 57511252
# ✔ Evil dead ii → 759521438
# ✔ Enemy mine → 12954863
# ✔ Big business → 50500248
# ✔ Altered states → 3516856
# ✔ Invisible man, the (aka thin air) →
# ✔ Duck soup → 727130025
# ✔ The lady eve → 48158808
# ✔ The palm beach story → 57498406
# ✔ Some kind of wonderful → 70892154
# ✔ Adventures in babysitting → 43802186
# ✔ Old gringo → 51050600
# ✔ Schindler's list → 54665740
# ✔ North → 10724046
# ✔ Back to the future part ii/part iii →
# ✔ Schindler's list → 54665740
# ✔ Innerspace → 50170155
# ✔ Troop beverly hills → 51929451
# ✔ The bell jar → 64565493
# ✔ The lady vanishes → 60054318
# ✔ Unholy city → 884809425
# ✔ Love potion #9 →
# ✔ Soapdish → 49040488
# ✔ Indiana jones and the temple of doom → 178323331
# ✔ Everything you always wanted to know about sex but were afraid to ask → 44569776
# ✔ Moonlight and valentino → 51579695
# ✔ Little women → 31288961
# ✔ Into the woods →
# ✔ Airheads → 48507493
# ✔ Money train →
# ✔ Groundhog day → 190702399
# ✔ Blue thunder → 42203396
# ✔ Big red one, the → 698452890
# ✔ Baby doll → 68042766
# ✔ Bodyguard, the →
# ✔ Bad boys → 294907667
# ✔ Baby, it's you → 911141093
# ✔ Big trouble in little china → 52391269
# ✔ Shaft's big score → 48685338
# ✔ Body double → 71360726
# ✔ Clan of the cave bear, the →
# ✔ Homicide → 10698487
# ✔ Craft, the → 757856159
# ✔ Flirting with disaster → 55669416
# ✔ Chud → 754662850
# ✔ Cat people → 50751449
# ✔ Christmas story, a → 46515984
# ✔ Cocoon → 55644473
# ✔ Coma → 45106588
# ✔ Eddie and the cruisers → 47968161
# ✔ Comfort and joy → 12518787
# ✔ Dillinger → 45474317
# ✔ Deadly trackers → 1104329894
# ✔ The getaway → 1018472805
# ✔ Daryl → 1280716282
# ✔ Dial m for murder → 851839
# ✔ Diamonds are forever → 74671223
# ✔ Don't look now → 50550850
# ✔ Falling in love → 48993315
# ✔ Fool for love → 10020503
# ✔ Father goose → 48503062
# ✔ License to kill → 320363639
# ✔ Hot shots!  part deux! → 256500177
# ✔ The great escape → 39457373
# ✔ The goonies → 137242344
# ✔ Garbo talks! → 693132568
# ✔ Glass key, the →
# ✔ Giant → 52393636
# ✔ Star trek → 51173454
# ✔ Malcolm x → 25412704
# ✔ Invasion of the body snatchers → 39983157
# ✔ Indian summer → 50612062
# ✔ Higgins and beech → 1029838875
# ✔ Spaceballs → 44018701
# ✔ Saint, the →
# ✔ Lady jane → 51282280
# ✔ The keep → 612362467
# ✔ Star trek vi → 24901828
# ✔ Sommersby → 42705753
# ✔ The people vs larry flynt → 35016741
# ✔ The fan → 191673824
# ✔ Er → 52941466
# ✔ Er → 52941466
# ✔ Er → 52941466
# ✔ A walk in the clouds → 51795389
# ✔ The vanishing → 56612411
# ✔ FM → 1042089664
# ✔ Guilty as sin → 52801936
# ✔ Bird cage, the →
# ✔ Stephen King's thinner → 49039203
# ✔ Lolita → 42670755
# ✔ Lorenzo's oil → 54984942
# ✔ Rush → 51254288
# ✔ The babe → 53188450
# ✔ She's the one → 45576653
# ✔ Till there was you → 55974195
# ✔ Hardcore → 1390129924
# ✔ Robin hood → 1019502404
# ✔ Hope and glory → 16405149
# ✔ The harder they fall → 51645011
# ✔ High anxiety → 65429492
# ✔ Serpico → 51168540
# ✔ Hushhush, sweet charlotte →
# ✔ Jaws 3/people 0 → 787874201
# ✔ Thunderheart → 41207936
# ✔ To die for → 50283521
# ✔ Dragon → 63245386
# ✔ Usual suspects, the → 1117839561
# ✔ Shakes the clown → 49978478
# ✔ Hang tough →
# ✔ Heaven's gate → 1051570160
# ✔ Doc hollywood → 43936560
# ✔ Under siege → 39886933
# ✔ The lonely guy → 1393687951
# ✔ Courage under fire → 33664955
# ✔ To wong foo, thanks for everythingjulie newmar →
# ✔ Night falls on manhattan → 40812701
# ✔ The evening star → 46428945
# ✔ Snow white in the black forest →
# ✔ Mobsters → 53310577
# ✔ Hollywood confidential →
# ✔ Whore → 1475032655
# ✔ The addams family → 1153553339
# ✔ Stand by for action → 809044945
# ✔ Fandango → 57707398
# ✔ Three days of the condor → 42679890
# ✔ Hail the conquering hero → 76832245
# ✔ River's edge → 49939458
# ✔ Bonnie and clyde → 42930701
# ✔ Key largo → 43638265
# ✔ Ride the high country → 62314662
# ✔ Chorus line, a →
# ✔ High plains drifter → 41440508
# ✔ Eight million ways to die → 987004638
# ✔ The rose → 52959783
# ✔ Beverly Hills cop → 48885432
# ✔ Rocky → 2851748
# ✔ Outrageous fortune → 43644806
# ✔ Star wars → 57186397
# ✔ Two for the road → 1397060
# ✔ The witches of eastwick → 70639602
# ✔ Repossessed → 325249193
# ✔ Unmarried woman, an → 5032357
# ✔ Man who knew too much, the →
# ✔ Brazil → 47813138
# ✔ Cliffhanger → 45436234
# ✔ Creepshow → 45343027
# ✔ Knots landing → 22381335
# ✔ Grass roots pt 1 →
# ✔ Man in the moon, the →
# ✔ Ace in the hole → 1052139785
# ✔ Backdraft → 40141988
# ✔ Prizzi's honor → 7976390
# ✔ Running on empty → 42423111
# ✔ Pat garrett and billy the kid → 759366
# ✔ Wall street → 45277669
# ✔ Red cars → 76784328
# ✔ Viva zapata → 1031110
# ✔ Irma la douce → 48062492
# ✔ Crying game, the → 29623267
# ✔ Commitments, the → 775008785
# ✔ Secret of my success, the →
# ✔ Ed wood → 32239181
# ✔ Gas food lodging → 53153432
# ✔ Choose me → 48406592
# ✔ A league of their own → 48529051
# ✔ Singles → 43614469
# ✔ Bram stoker's dracula → 173022834
# ✔ Desperado → 53040080
# ✔ Needful things → 50572681
# ✔ Point of no return → 45658965
# ✔ M butterfly → 18559427
# ✔ Children of the corn II → 893437274
# ✔ Hero → 43409400
# ✔ Hard target → 40797641
# ✔ Amos and andrew → 1323489272
# ✔ Sleepless in seattle → 53371893
# ✔ Billy madison → 57376019
# ✔ Serial mom → 212225350
# ✔ Bad girls → 58868466
# ✔ Fire in the sky → 56843572
# ✔ Tombstone → 40763305
# ✔ Single white female → 41370281
# ✔ Greedy → 40730228
# ✔ Wild bill → 46822967
# ✔ 2 days in the valley → 41508180
# ✔ Jeffrey → 28721518
# ✔ Iq → 990646804
# ✔ The stand → 20490025
# ✔ The stand → 20490025
# ✔ The stand → 20490025
# ✔ The stand → 20490025
# ✔ Set it off → 436098866
# ✔ Philadelphia → 41561706
# ✔ Jennifer eight → 44734986
# ✔ Geronimo → 6561463
# ✔ Quick and the dead, the → 1325717382
# ✔ Demolition man → 40062754
# ✔ Murder in the first → 44617671
# ✔ Drop zone → 611482646
# ✔ The basketball diaries → 58725267
# ✔ Beverly Hills, 90210  "pilot episode" → 1037193607
# ✔ Major league II → 45323503
# ✔ I love trouble → 43329585
# ✔ Rumble fish → 1500063
# ✔ Cliffhanger → 45436234
# ✔ Star wars → 57186397
# ✔ The firm → 51926559
# ✔ Saturday night fever → 154725617
# ✔ Princess bride, the → 1053909761
# ✔ Public eye, the → 191121939
# ✔ Bad company → 53310517
# ✔ Spider-man → 769425349
# ✔ Air up there, the →
# ✔ Nell → 54359896
# ✔ Nobody's fool → 53033533
# ✔ Beverly hills cop iii → 49013073
# ✔ Man's best friend → 52765724
# ✔ Ronnie rocket → 961036331
# ✔ My life → 158129
# ✔ Fluke → 47173079
# ✔ Twin peaks → 176193836
# ✔ Saboteur → 71524174
# ✔ Real blonde, the →
# ✔ Alien → 53816173
# ✔ Planes, trains and automobiles → 1003325439
# ✔ Don juan demarco → 40140338
# ✔ Preacher's wife, the →
# ✔ Say anything → 50059393
# ✔ Punchline → 973952156
# ✔ Empire records → 52474263
# ✔ Fletch → 123243401
# ✔ A river runs through it → 42955743
# ✔ Other people's money → 60420504
# ✔ Angels in the outfield → 49659690
# ✔ Aliens → 54388628
# ✔ Of mice and men → 51812005
# ✔ To catch a thief → 124049651
# ✔ Harper → 74813549
# ✔ Little big man → 52493212
# ✔ Countryman →
# ✔ Hustler, the → 680057155
# ✔ Jungle fever → 49223396
# ✔ The big sleep → 70662384
# ✔ City hall → 44588198
# ✔ Bushwhacked →
# ✔ White man's burden → 47180917
# ✔ Funny bones → 53280045
# ✔ Airplane ii → 51745865
# ✔ Nothing in common → 49502101
# ✔ Beetlejuice in love →
# ✔ Dogfight → 51638828
# ✔ Sign, the → 11804136
# ✔ Getting even with dad → 30714081
# ✔ Homicide → 24373481
# ✔ Hoosiers → 49001236
# ✔ Slaves of new york → 13426131
# ✔ Desperately seeking susan → 12315649
# ✔ Field of dreams → 54802158
# ✔ Two lane blacktop → 243474081
# ✔ Sea of love → 52164441
# ✔ Only the lonely → 61333991
# ✔ Lean on me → 43757254
# ✔ Problem child 2 → 54861093
# ✔ Before and after → 1089836862
# ✔ Mountains of the moon → 49744727
# ✔ Pet sematary → 9576009
# ✔ Patriot games → 51946735
# ✔ City slickers ii → 52098902
# ✔ Prince of tides, the → 732664703
# ✔ Fargo → 35017041
# ✔ Revenge → 21106320
# ✔ Taxi driver → 22950544
# ✔ Tremors 2 → 1411251212
# ✔ Angel → 80020010
# ✔ Married to the mob → 44708176
# ✔ Coming to america → 123960470
# ✔ Stealing home → 43823903
# ✔ Legends of the fall → 45227418
# ✔ Gremlins ii →
# ✔ Miller's crossing → 671862433
# ✔ The long kiss goodnight → 40600118
# ✔ Destiny turns on the radio → 801209958
# ✔ Bulletproof → 123083024
# ✔ Now and then → 45436744
# ✔ Playing god → 1129586287
# ✔ Ghost → 84915075
# ✔ National lampoon's the joy of sex; a dirty love story → 122354258
# ✔ The last picture show → 4775112
# ✔ The great moment → 76832254
# ✔ 1941 → 41595542
# ✔ A perfect world → 57013463
# ✔ Low life, the →
# ✔ Scream → 1301399829
# ✔ The great white hype → 647769013
# ✔ The cards are wild →
# ✔ Beautiful girls → 42052279
# ✔ Fear → 44078343
# ✔ The underneath → 44569522
# ✔ The jungle book → 32171667
# ✔ Look who's talking → 40552286
# ✔ Murphy's romance → 76062928
# ✔ Man who would be king, the →
# ✔ The freshman → 41617452
# ✔ Fedora → 891396626
# ✔ Cousins → 48993668
# ✔ License to drive → 18228239
# ✔ The miss firecracker contest → 11766211
# ✔ My family → 54810702
# ✔ Seven hours to judgement →
# ✔ Taking off → 3077192
# ✔ Hair → 41397278
# ✔ Ragtime → 56946497
# ✔ Ditto → 508737747
# ✔ Someone to watch over me → 156278849
# ✔ True believer → 156271443
# ✔ Blaze of glory → 13905066
# ✔ Devil's advocate → 50752589
# ✔ In a lonely place → 51955874
# ✔ The music box → 52331438
# ✔ Miami blues → 51254701
# ✔ Dead ringers → 60555211
# ✔ The ticking man →
# ✔ The butler → 1265423429
# ✔ The guest → 896829221
# ✔ K-pax → 49313282
# ✔ The bourne supremacy → 56401976
# ✔ Fierce people → 48544892
# ✔ Collateral → 56607957
# ✔ Veronica mars → 869367532
# ✔ The paperboy → 817247592
# ✔ And so it goes → 892336459
# ✔ The brass teapot → 842423903
# ✔ Extraordinary measures → 525349060
# ✔ Begin again → 889881195
# ✔ Her → 875580865
# ✔ Prisoners → 862830196
# ✔ The claim → 46870650
# ✔ You again → 677116596
# ✔ Bad education → 865227575
# ✔ Love is strange → 897517613
# ✔ The zero theorem → 897438501
# ✔ Sweetwater → 1380360338
# ✔ Gambit → 877888181
# ✔ Sex tape → 890150906
# ✔ 2 guns → 862083306
# ✔ Paranoia → 859204474
# ✔ The man who shook the hand of Vincente Fernandez →
# ✔ Very good girls → 883431522
# ✔ Red 2 → 859832246
# ✔ Into the storm → 892562528
# ✔ The secret life of Walter Mitty →
# ✔ Trust me → 883633577
# ✔ Disconnect → 853625544
# ✔ 8 heads in a duffel bag /$cwritten by Tom Schulman →
# ✔ Just between frineds /$cwritten by Allan Burns →
# ✔ Lush life /$cwritten by Michael Elias →
# ✔ Violets are blue /$cwritten by Naomi Foner →
# ✔ Analyze this → 191954051
# ✔ American history x → 41151412
# ✔ Mystery men → 43332663
# ✔ Meet joe black → 41167716
# ✔ Rounders → 55771839
# ✔ Never been kissed → 41171127
# ✔ You've got mail → 187316396
# ✔ Teaching mrs tingle → 43350560
# ✔ Out-of-towners, the →
# ✔ Mod squad, the →
# ✔ Austin powers → 1001494513
# ✔ 8mm → 156273966
# ✔ Entrapment → 49835768
# ✔ Fight club → 56072293
# ✔ Love letter, the →
# ✔ Mafia! → 41207637
# ✔ Living out loud → 41225976
# ✔ Life → 42739496
# ✔ General's daughter, the →
# ✔ Mighty joe young → 45321716
# ✔ Nurse betty → 46654076
# ✔ What dreams may come → 52454321
# ✔ Other sister, the →
# ✔ Replacements, the →
# ✔ Boondock saints, the →
# ✔ Wonder boys → 46438667
# ✔ Reindeer games → 46734386
# ✔ Skulls, the → 1043936021
# ✔ Any given sunday → 44948233
# ✔ Bone collector, the →
# ✔ Quills → 35361861
# ✔ Three kings → 43802169
# ✔ Nutty professor ii, the → 45545975
# ✔ Rocky and bullwinkle movie, the →
# ✔ Big daddy → 43359324
# ✔ Sleepy hollow → 44123122
# ✔ Frequency → 45278306
# ✔ Gloria → 41435177
# ✔ Cradle will rock, the → 42643454
# ✔ Keeping the faith → 45196028
# ✔ For love of the game → 43760062
# ✔ Lost souls → 46377639
# ✔ Requiem for a dream → 45072337
# ✔ Bell, book and candle → 50278573
# ✔ Gossip → 45278428
# ✔ Here on earth → 44764757
# ✔ My best friend's wedding → 48011840
# ✔ Sleepy hollow → 44123122
# ✔ Election → 43927528
# ✔ Just between friends → 54456421
# ✔ Stake-out → 699829039
# ✔ Being john malkovich → 1052994442
# ✔ Boys don't cry → 44023460
# ✔ Talented mr ripley, the → 1184605678
# ✔ Crush, the → 801249435
# ✔ Love story → 55360
# ✔ Traffic → 46944435
# ✔ Little nicky → 46815970
# ✔ Nurse betty → 46654076
# ✔ Playing by heart → 42190466
# ✔ Watcher, the →
# ✔ Shadow of the vampire → 47043311
# ✔ Chocolat → 47788520
# ✔ Fight club → 56072293
# ✔ Amadeus → 7643335
# ✔ English patient, the → 913630788
# ✔ Thin line between love & hate, a →
# ✔ Chariots of fire → 57450313
# ✔ Shrek → 1032008652
# ✔ Quills → 35361861
# ✔ Star wars → 57186397
# ✔ West wing, the → 76787755
# ✔ Life is beautiful → 40397627
# ✔ Hours, the → 1042883330
# ✔ Lost in translation → 53816204
# ✔ Finding nemo → 52890387
# ✔ Swat → 796786384
# ✔ Mystic river → 54893194
# ✔ Cheaper by the dozen → 62364591
# ✔ Ladykillers, the →
# ✔ Hope & faith → 1518500888
# ✔ Gothika → 54347295
# ✔ American splendor → 54975921
# ✔ Alex & emma → 922682292
# ✔ Lord of the rings → 52199488
# ✔ Joan of arcadia → 58400500
# ✔ CSI → 57206171
# ✔ Bringing down the house → 52220430
# ✔ Seabiscuit → 53072457
# ✔ In america → 54792166
# ✔ Singing detective, the →
# ✔ Dirty pretty things → 54911779
# ✔ City of god → 53188739
# ✔ Hospital → 53154258
# ✔ Fun with dick and jane → 62500327
# ✔ Year of the dragon → 60656449
# ✔ Midnight express → 182871602
# ✔ Postman always rings twice → 54060256
# ✔ Sunset → 41591686
# ✔ Salvador → 47107589
# ✔ Housekeeping → 752302902
# ✔ M*a*s*h → 56773668
# ✔ Johnny got his gun → 108365
# ✔ Crimes of the heart → 8570269
# ✔ The January man → 49677391
# ✔ Miracle on 34th street → 892179385
# ✔ The bloodhounds of broadway → 55472232
# ✔ Three men and a baby → 607205660
# ✔ Naked gun →
# ✔ Miracle mile → 900298052
# ✔ Leprechaun → 43792448
# ✔ Mississippi burning → 46993423
# ✔ Mosquito coast → 43701444
# ✔ Robocop → 877833213
# ✔ Disturbing behavior → 40808960
# ✔ Thunder heart → 27413260
# ✔ Gorillas in the mist → 41631744
# ✔ Octopussy → 76832387
# ✔ Buster → 1311165503
# ✔ Scrooged → 50033195
# ✔ The china syndrome → 56815743
# ✔ Falling from grace → 56943323
# ✔ Vibes → 312441694
# ✔ Blaze → 62076890
# ✔ Coneheads → 47813540
# ✔ Wise guys → 156281374
# ✔ Cocoon II → 1233083802
# ✔ Dad → 60586449
# ✔ Black orpheus →
# ✔ Candyman → 56319399
# ✔ Night and the city → 308528738
# ✔ Tucker → 45447420
# ✔ The fly ii → 61347165
# ✔ Who framed roger rabbit → 51269419
# ✔ Beetlejuice → 1090217282
# ✔ Twenty bucks → 60709939
# ✔ Ghostbusters ii → 63161930
# ✔ Short circuit → 51907164
# ✔ !three amigos! → 44722520
# ✔ Hickok and cody →
# ✔ Twins → 40142099
# ✔ Suspension →
# ✔ Hider in the house → 801247655
# ✔ A bright shining lie → 870904063
# ✔ Vice-versa → 55082974
# ✔ The playboys → 54886973
# ✔ What's eating gilbert grape → 23584283
# ✔ Steel magnolias → 17684004
# ✔ Sunrise → 56411406
# ✔ Gung ho → 50257838
# ✔ Mickey & maude → 156277816
# ✔ Running man, the →
# ✔ The river → 45199620
# ✔ The year of the comet → 950527533
# ✔ For whom the bell tolls →
# ✔ Sister act → 28900719
# ✔ The boy who could fly → 156272433
# ✔ Rocky iv → 57417312
# ✔ Rain man → 54389736
# ✔ The white company → 1142633907
# ✔ Mutiny on the bounty → 74336895
# ✔ After dark my sweet → 50031160
# ✔ We're no angels → 20754517
# ✔ Dead bang → 43832398
# ✔ Class action → 57587534
# ✔ National lampoon's christmas vacation → 53295703
# ✔ Children's hour, the → 760917111
# ✔ Bad boys → 45090765
# ✔ The great santini → 43492244
# ✔ Postcards from the edge → 15316291
# ✔ Gallipoli → 8474887
# ✔ Wuthering heights → 823870296
# ✔ Satan's sandbox →
# ✔ Tango & cash → 41579765
# ✔ A letter to three wives → 57300248
# ✔ Valmont → 50733699
# ✔ Oldest living confederate widow tells all → 56943374
# ✔ Oldest living confederate widow tells all → 56943374
# ✔ The adventures of buckaroo banzai → 48692610
# ✔ Runaway train → 40808954
# ✔ Norma rae → 46804158
# ✔ Real mccoy, the →
# ✔ 2001 → 449499
# ✔ The best man → 706077982
# ✔ The stars fell on henrietta → 701713021
# ✔ Shadowlands → 23769645
# ✔ Cadillac man → 49631422
# ✔ Sgt rock → 170966254
# ✔ Lethal weapon 2 → 732733396
# ✔ Wilder napalm → 55136194
# ✔ Crucible, the → 34486358
# ✔ The cotton club → 13334076
# ✔ Opportunity knocks → 53707436
# ✔ Rambo → 213415916
# ✔ Quick change → 64404489
# ✔ Head office → 60526020
# ✔ Can't buy me love → 50530978
# ✔ Competition, the →
# ✔ Havana → 41323735
# ✔ Mchale's navy →
# ✔ Tom Jones → 988399
# ✔ Awakenings → 40987802
# ✔ Poltergeist ii- the other side → 13693387
# ✔ Treasure →
# ✔ Trading places [black and white] → 27357784
# ✔ The outsiders → 245535524
# ✔ Marked for death → 57655112
# ✔ Trespass → 57481650
# ✔ Unstrung heroes → 52444622
# ✔ The hard way → 54033987
# ✔ Heart and souls → 42249885
# ✔ The kiss → 48567818
# ✔ Relentless → 182574289
# ✔ Mystic pizza → 46697075
# ✔ Pacific heights → 43645620
# ✔ Narrow margin → 40420242
# ✔ Mad dog and glory → 851999127
# ✔ St elmo's fire ii →
# ✔ The bonfire of the vanities → 43740477
# ✔ Leaving normal → 813029946
# ✔ The two jakes → 180772481
# ✔ Erik the viking → 20417216
# ✔ Reversal of fortune → 46646598
# ✔ Internal affairs → 41094575
# ✔ Flatliners → 1011631850
# ✔ Year of frank sinatra, the →
# ✔ White sands → 44846482
# ✔ Point break → 939440171
# ✔ The pelican brief → 41543820
# ✔ Nostromo → 792957464
# ✔ Uhf → 49992355
# ✔ Dying young → 57938566
# ✔ The american president → 9759896
# ✔ Coupe de ville → 785899634
# ✔ North dallas forty →
# ✔ Tales from the crypt presents → 56803179
# ✔ Forbidden planet → 44606831
# ✔ Predator → 1061313537
# ✔ Sweet tooth →
# ✔ Love at first bite → 60718143
# ✔ Ferris bueller's day off → 1313483735
# ✔ Bad influence → 51197089
# ✔ Grace of my heart → 42269982
# ✔ The grifters → 50741822
# ✔ Pee wee's big adventure → 921939461
# ✔ Man with one red shoe, the →
# ✔ Young guns → 52640545
# ✔ My bodyguard → 48916094
# ✔ Fugitive, the →
# ✔ How to be a player → 52863292
# ✔ Sleepless in seattle → 53371893
# ✔ Indecent proposal → 49235523
# ✔ Queen's logic → 52941155
# ✔ Welcome home, roxy carmichael → 126894029
# ✔ Airplane! → 61370131
# ✔ Dolores claiborne → 275278519
# ✔ Ryan's daughter → 62596943
# ✔ The squall → 741331764
# ✔ Guilty by suspicion → 40355456
# ✔ Sabrina → 48841426
# ✔ Mrs doubtfire →
# ✔ My blue heaven → 45443375
# ✔ Executive decision → 40899607
# ✔ Valley of the dolls →
# ✔ Working girls → 1202024628
# ✔ Safe → 894261172
# ✔ My father the hero → 52096084
# ✔ Harrow alley → 18474634
# ✔ Man facing southeast →
# ✔ Far from home → 48380085
# ✔ American buffalo → 3386971
# ✔ Force of evil → 55491478
# ✔ Liar, liar → 45199272
# ✔ Death of a salesman → 19708989
# ✔ In the night → 654135571
# ✔ The odd couple → 1458362710
# ✔ The great unknown →
# ✔ Separate lives →
# ✔ Pope of pop, the →
# ✔ Darkman iii → 60404397
# ✔ Women on wheels → 801271257
# ✔ Shane → 45084868
# ✔ Hard to kill → 373854666
# ✔ Mermaids → 46567072
# ✔ Seaquest → 423349917
# ✔ The exorcist iii → 1411767910
# ✔ Four rooms → 45129898
# ✔ One night stand → 793207295
# ✔ The island of dr moreau → 39550269
# ✔ Manhattan project, the → 15639167
# ✔ The indian in the cupboard → 47246208
# ✔ Hill street blues → 62257093
# ✔ The rich man's wife → 49697875
# ✔ The rock → 39967332
# ✔ Relic → 41631700
# ✔ Key west →
# ✔ Good sports →
# ✔ The green hornet →
# ✔ Exit zero → 945638396
# ✔ Hardwired → 992487480
# ✔ Mortal kombat → 38148764
# ✔ Brain donors → 885619515
# ✔ What about bob? → 44846342
# ✔ Dudes → 939559673
# ✔ Dark half, the →
# ✔ Hook → 24987813
# ✔ Reel to reel → 795758138
# ✔ Flintstones, the → 32626945
# ✔ My cousin vinny → 44911046
# ✔ The rocketeer → 42462408
# ✔ Vi warshawski → 970752931
# ✔ Point break → 815416707
# ✔ Perdition's flame →
# ✔ Sixth man, the →
# ✔ Gabriel's fire → 30486700
# ✔ Live nude girls → 828560853
# ✔ Lenny →
# ✔ The fantastic four → 423688783
# ✔ Hot shots! → 52587342
# ✔ Hoffa → 54541994
# ✔ Gladiators → 56259262
# ✔ Crash → 36086755
# ✔ Meeting venus → 405337860
# ✔ Housesitter → 40141643
# ✔ Donnie brasco → 45596660
# ✔ Matilda → 60496505
# ✔ Without remorse → 497182392
# ✔ Freeway → 43644813
# ✔ Mother's instinct, a →
# ✔ Jack → 55952577
# ✔ Alfie → 46381459
# ✔ Mr and mrs loving → 61145322
# ✔ Cable guy, the →
# ✔ Last man standing → 49347742
# ✔ Commando → 83842709
# ✔ Superman → 12673431
# ✔ The lords of discipline → 64428120
# ✔ Tell them willie boy is here → 639300593
# ✔ Lionheart → 506571235
# ✔ The eighteenth angel → 52765687
# ✔ Thirtysomething → 999884032
# ✔ Medicine man → 42697459
# ✔ Indiana jones and the last crusade → 178323353
# ✔ China moon → 49311453
# ✔ Firestorm → 606746913
# ✔ Ghost ship →
# ✔ Spectre → 778874801
# ✔ Curdled → 70247492
# ✔ Quest, the →
# ✔ I was a male war bride → 54932206
# ✔ Kelly's heroes → 44733271
# ✔ The jewel of the nile → 13667376
# ✔ Michael → 39551405
# ✔ Twelve days of christmas, the →
# ✔ Smokescreen →
# ✔ Dark streets →
# ✔ Used people → 741692724
# ✔ Police story → 22247931
# ✔ Diagnosis of a murder →
# ✔ Last wave, the → 1176190985
# ✔ The wrong man → 56365716
# ✔ Alfred hitchcock presents →
# ✔ Kiss the girls → 40222234
# ✔ Alaska →
# ✔ Alien avengers → 801247299
# ✔ Frenzy → 70922484
# ✔ Lifeboat → 61281777
# ✔ The trouble with harry → 46479600
# ✔ Spellbound → 260574016
# ✔ Topaz → 70667487
# ✔ Torn curtain → 62893272
# ✔ The milagro beanfield war → 60562678
# ✔ Machine gun kelly → 83596131
# ✔ This is your life → 824725396
# ✔ Phenomenon → 40660621
# ✔ Going west → 62564929
# ✔ Fled → 911549023
# ✔ The pope must die → 796047242
# ✔ For the boys → 56588333
# ✔ Country → 53928242
# ✔ Campus man → 53227071
# ✔ The bradys → 1109388804
# ✔ Starting over → 60769751
# ✔ Patriot games → 51946735
# ✔ Rebel without a cause → 60554665
# ✔ Manhattan murder mystery → 49996116
# ✔ Network → 63791577
# ✔ Parenthood → 745916958
# ✔ The doors → 1230341093
# ✔ Four weddings and a funeral → 227001650
# ✔ Fame → 467413044
# ✔ Swing shift → 821223942
# ✔ The way we were → 278158
# ✔ A streetcar named desire → 55286308
# ✔ Home alone → 900913272
# ✔ Beverly hills cop ii →
# ✔ Heaven and earth - subtitled "troi va dat" →
# ✔ Talk radio → 841172549
# ✔ Boyz in the hood → 85855326
# ✔ Bullitt → 38480591
# ✔ American gigolo → 4493399
# ✔ Frankie and Johnny → 18281034
# ✔ The sure thing → 53158253
# ✔ The fly → 62386147
# ✔ Clockwork orange, a → 2755424
# ✔ Maverick → 40599535
# ✔ She's having a baby → 46887306
# ✔ Speed → 60934187
# ✔ Blade runner → 43636330
# ✔ Psycho ii → 61691236
# ✔ 48 hours → 191100562
# ✔ The great train robbery → 1175916
# ✔ Clear and present danger → 51854729
# ✔ Blue collar → 551787691
# ✔ Five easy pieces → 24002416
# ✔ Repo man → 17104487
# ✔ A boy called hate → 801214667
# ✔ Alien → 999866379
# ✔ Fast times at ridgemont high → 7574664
# ✔ Shampoo → 51522941
# ✔ Out of africa → 47699599
# ✔ Against all odds → 52937388
# ✔ Born on the Fourth of July → 56664754
# ✔ Scent of a woman → 39812439
# ✔ Sunset boulevard → 794328499
# ✔ Swing shift →
# ✔ Howard's end → 57206191
# ✔ Marquis de sade →
# ✔ Lenny → 49674765
# ✔ Forrest gump →
# ✔ The silence of the lambs → 47758304
# ✔ Jagged edge → 44429177
# ✔ Clue → 49937216
# ✔ Pretty woman → 27053960
# ✔ A midnight clear → 50012169
# ✔ Thelma and louise → 34243523
# ✔ My own private idaho → 57206229
# ✔ In the line of fire → 46686859
# ✔ Jacob's ladder → 22543836
# ✔ Dirty Harry → 234235133
# ✔ Ghandi → 65957552
# ✔ Cry freedom → 192011903
# ✔ Richie rich → 58424623
# ✔ Scarlet letter, the →
# ✔ Deer hunter, the → 968799972
# ✔ Missing → 56961188
# ✔ Deliverance → 58614
# ✔ Pulp fiction → 43819604
# ✔ True romance → 43286890
# ✔ Kiss of death → 62208250
# ✔ Basic instinct → 34741365
# ✔ One flew over the cuckoo's nest → 38148696
# ✔ Working girl → 46770992
# ✔ Lawrence of arabia → 1499151078
# ✔ All that jazz → 223337527
# ✔ Fish called wanda, a → 59189361
# ✔ Hunt for red october, the →
# ✔ Robin hood → 44477808
# ✔ Under fire → 48399493
# ✔ Vertigo → 43325609
# ✔ Citizen kane → 48011132
# ✔ Nypd blue → 67719151
# ✔ Terminator ii → 52400400
# ✔ American graffiti → 40402473
# ✔ Kramer vs kramer → 47977290
# ✔ Grand canyon → 46517331
# ✔ Trouble in paradise → 51283471
# ✔ Gorky park → 45645087
# ✔ Lethal weapon → 732733396
# ✔ Flashdance → 50764078
# ✔ Double indemnity → 43521015
# ✔ Even cowgirls get the blues → 29753110
# ✔ Butch cassidy and the sundance kid → 44096427
# ✔ Apartment, the →
# ✔ Broadcast news → 18192079
# ✔ The accused → 49233886
# ✔ Batman → 704433479
# ✔ Waist deep → 70834684
# ✔ The tv set → 163582025
# ✔ Stepford wives, the →
# ✔ Secret window → 54902420
# ✔ Flightplan → 62198989
# ✔ An education → 496323356
# ✔ 16 blocks → 66144527
# ✔ Enchanted → 184955338
# ✔ Dark ride →
# ✔ Greenberg → 611168793
# ✔ Fur → 7466642
# ✔ The switch → 696641922
# ✔ Failure to launch → 67619053
# ✔ Talk to me → 166585172
# ✔ Walking tall → 55696542
# ✔ Sentinel, the → 834644206
# ✔ Southland tales → 189077917
# ✔ Smokin' aces → 85269817
# ✔ Final destination 3 → 65519773
# ✔ Astronaut farmer, the →
# ✔ American gangster → 184742249
# ✔ Date night → 639609683
# ✔ Dead girl, the →
# ✔ Can't hardly wait → 40402476
# ✔ days of summer → 455558286
# ✔ Breakup, the →
# ✔ I love you, beth cooper → 76143550
# ✔ Public enemies → 437046185
# ✔ Tourist, the →
# ✔ Goldeneye → 42949144
# ✔ Sphere → 39531369
# ✔ Goodfellas → 42881293
# ✔ Superman →
# ✔ Jaws → 793612
# ✔ True romance → 43286890
# ✔ Night of the hunter → 43832229
# ✔ Enemy of the state → 216748265
# ✔ Negotiator, the →
# ✔ Midnight cowboy → 39481827
# ✔ Art school confidential → 68623994
# ✔ Break-up, the → 1268556110
# ✔ Grandview usa → 1518207078
# ✔ Brokeback mountain → 63201832
# ✔ Deterrence → 45174109
# ✔ Capote → 62709417
# ✔ Spanglish → 57491001
# ✔ Tales of the city → 855019046
# ✔ Shape of things, the → 1341684284
# ✔ Death to smoochy → 50497100
# ✔ Frida → 50752847
# ✔ Limbo → 43148126
# ✔ Lulu on the bridge → 38936633
# ✔ Spun → 52362423
# ✔ Orange county → 49960992
# ✔ Laurel canyon → 52220393
# ✔ Thirteen → 53816224
# ✔ Real women have curves → 36500416
# ✔ Wet hot american summer → 53224716
# ✔ Friends with money → 71198085
# ✔ Napoleon dynamite → 56588471
# ✔ Adaptation → 51979880
# ✔ Omen 666, the →
# ✔ Matador, the →
# ✔ Masked and anonymous → 54025774
# ✔ Sideways → 57345729
# ✔ Dawn of the dead → 56820718
# ✔ Spartan → 54984966
# ✔ Munich → 65185300
# ✔ In her shoes → 62287040
# ✔ Chumscrubber, the →
# ✔ Gridiron gang, the → 1269076158
# ✔ Harold and kumar go to white castle → 922672325
# ✔ Kiss kiss bang bang → 63931059
# ✔ Silver city → 57397476
# ✔ Rundown → 53949809
# ✔ Italian job, the →
# ✔ Taking lives →
# ✔ Constantine → 60131088
# ✔ Me, you, and everyone we know → 696447321
# ✔ Little children → 79663432
# ✔ Criminal → 215908
# ✔ Stir of echoes, a →
# ✔ Salton sea, the →
# ✔ Contender, the →
# ✔ Ninth gate, the →
# ✔ Bedazzled → 46438850
# ✔ House on haunted hill → 44485940
# ✔ Return to me → 778047006
# ✔ But i'm a cheerleader → 52964568
# ✔ Notting hill-2nd draft →
# ✔ Rodger dodger →
# ✔ Thirteen conversations about one thing → 50847983
# ✔ Fugitive, the →
# ✔ The wild bunch → 62386408
# ✔ Boomerang → 51881909
# ✔ Things to do in denver when you're dead → 42386440
# ✔ Boys on the side → 41495133
# ✔ Cotton club, the →
# ✔ Star trek → 31491225
# ✔ Forrest gump → 47981929
# ✔ Reality bites → 55987955
# ✔ The princess bride → 732732595
# ✔ The english patient → 55881775
# ✔ Déjà vu → 133550861
# ✔ Nanny diaries, the →
# ✔ 1408 → 156824483
# ✔ Soloist, the →
# ✔ Merchant of venice, the →
# ✔ Something's gotta give → 53997078
# ✔ Final destination, the →
# ✔ Surrogates → 460724411
# ✔ Mist, the →
# ✔ Ghosts of girlfriends past → 426059701
# ✔ National treasure 2 → 191750531
# ✔ Hellboy 2 → 234521249
# ✔ Ghost town → 271523124
# ✔ Cirque du freak → 476335840
# ✔ Legion → 514206122
# ✔ Igor → 276782831
# ✔ Death race → 261349517
# ✔ Choke → 288719259
# ✔ Sorority row → 492438258
# ✔ Body of lies → 277055292
# ✔ Jennifer's body → 460737422
# ✔ Planet 51 → 492431985
# ✔ Death sentence → 180299101
# ✔ Strangers, the → 1048253886
# ✔ 30 days of night → 51980424
# ✔ Observe and report → 429138652
# ✔ Ruins, the → 1351567948
# ✔ Fracture → 133652934
# ✔ Tenacious d in the pick of destiny → 77501579
# ✔ Visitor, the →
# ✔ Hot tub time machine → 612013243
# ✔ Shoot 'em up → 174495391
# ✔ Before the devil knows your dead →
# ✔ When in rome → 528876726
# ✔ This Christmas → 244206306
# ✔ Barbarian invasions, the →
# ✔ American pie → 43080735
# ✔ 2 fast 2 furious → 52710118
# ✔ Friday night lights → 56938708
# ✔ The kingdom of heaven → 60886192
# ✔ The aviator → 58534463
# ✔ Never die alone →
# ✔ Hidalgo → 55492221
# ✔ Magnificent ambersons, the →
# ✔ Million dollar baby → 59134326
# ✔ School of rock, the → 928140351
# ✔ Hotel rwanda → 57673690
# ✔ Elf → 1198376997
# ✔ Unbreakable → 732739431
# ✔ Ray → 1042837340
# ✔ Kinsey → 57560295
# ✔ Imaginary heroes → 58996289
# ✔ A very long engagement → 922681929
# ✔ High fidelity → 45552475
# ✔ How stella got her groove back → 40747861
# ✔ Shrek 2 → 56116208
# ✔ Monster-in-law → 863602801
# ✔ Along came polly → 54534211
# ✔ Ice princess → 59824467
# ✔ The girl next door → 55759574
# ✔ Dukes of hazzard → 61698906
# ✔ The battle of shaker heights → 54208313
# ✔ The wedding crashers → 61728663
# ✔ Thumbsucker → 62287044
# ✔ Newhart →
# ✔ Family law → 83980929
# ✔ The fugitive → 423540926
# ✔ Earth → 1485509629
# ✔ Crash → 61432295
# ✔ The fugitive → 47151448
# ✔ Spoils of war →
# ✔ Idle hands → 55662030
# ✔ Blades →
# ✔ Alias →
# ✔ Bowfinger → 43314062
# ✔ Gajin →
# ✔ The black box → 706077938
# ✔ Ten things I hate about you → 42624432
# ✔ Risky business → 236209873
# ✔ Verdict, the →
# ✔ Hairspray → 51992171
# ✔ Apocalypse now → 46851678
# ✔ Baby boom → 46336822
# ✔ A passage to india → 46843162
# ✔ Parallax view, the → 223151167
# ✔ Searchers, the → 222856320
# ✔ Poison ivy iii →
# ✔ Jfk → 53344730
# ✔ Street fighter → 302368396
# ✔ Christmas in July → 76832272
# ✔ Clockers → 24906370
# ✔ Kiss of death → 56410905
# ✔ Crossing guard, the →
# ✔ Color of night, the →
# ✔ Godfather, the → 259719732
# ✔ The abyss → 49503915
# ✔ The new age → 945699740
# ✔ Barcelona → 942565169
# ✔ In the mouth of madness → 44160688
# ✔ Milk money → 53061432
# ✔ It could happen to you → 749857594
# ✔ The river wild → 40612850
# ✔ The candidate → 39227805
# ✔ Species → 57192122
# ✔ Johnny mnemonic → 32522354
# ✔ Flesh and bone → 49235305
# ✔ Hudsucker proxy, the →
# ✔ The doors → 1230341093
# ✔ Hud → 53295694
# ✔ When harry met sally → 20827762
# ✔ The hand that rocks the cradle → 40729362
# ✔ Terminal velocity → 46852205
# ✔ Time after time → 50398380
# ✔ Seven percent solution, the →
# ✔ Midnight run → 52413599
# ✔ Bye bye, love → 58592093
# ✔ Devil in a blue dress → 34667893
# ✔ Exit to eden → 49677123
# ✔ Hackers → 43868379
# ✔ Ready to wear → 812072551
# ✔ Lord of illusions → 40198975
# ✔ Crisis in the hot zone →
# ✔ The last of the mohicans → 45952670
# ✔ Thing called love, the →
# ✔ Gloria → 51845611
# ✔ My girl ii → 123356634
# ✔ Three of hearts → 156274603
# ✔ Mask → 55704169
# ✔ Body heat → 72576441
# ✔ Stagecoach → 211713
# ✔ The color of money → 43739560
# ✔ Peggy sue got married → 51490280
# ✔ Shock treatment → 71312337
# ✔ Witness → 982373809
# ✔ Melvin and howard →
# ✔ Blankman → 49219020
# ✔ Blue velvet → 50186541
# ✔ Top gun → 32995886
# ✔ Never say never again → 45231826
# ✔ Places in the heart → 48522326
# ✔ My favorite year → 50245709
# ✔ Romancing the stone → 11973038
# ✔ Mr wonderful → 47647008
# ✔ Klute → 49276167
# ✔ Casablanca → 44103110
# ✔ Slap shot → 49483631
# ✔ Zoot suit → 55229162
# ✔ Small in the saddle →
# ✔ Bloodstone →
# ✔ The best years of our lives → 44613484
# ✔ Romeo is bleeding → 49525968
# ✔ Dangerous liaisons → 28549808
# ✔ James dean → 1144632296
# ✔ Kagemusha → 57031668
# ✔ Edward scissorhands → 62286653
# ✔ Naked lunch → 53457727
# ✔ How green was my valley → 51453150
# ✔ Warriors of virtue → 45099267
# ✔ Ghosts of mississippi, the →
# ✔ Max dugan returns → 61512823
# ✔ Body and soul → 43563503
# ✔ It's a wonderful life → 13456538
# ✔ Sacred cows →
# ✔ Dead again → 52765679
# ✔ Barton fink → 52343765
# ✔ The king of comedy → 51489870
# ✔ Spanking the monkey → 62746288
# ✔ Spanking the monkey → 62746288
# ✔ Wizard of oz, the → 19390516
# ✔ Sophie's choice → 43583260
# ✔ Pope of greenwich village, the →
# ✔ Being there → 161702
# ✔ Footloose → 940364841
# ✔ Black widow → 54369709
# ✔ It happened one night → 43802345
# ✔ Reuben, reuben → 843955430
# ✔ Pretty in pink → 70927461
# ✔ The paper chase → 156216
# ✔ State and main → 45857389
# ✔ You can count on me → 48053807
# ✔ Cider house rules, the → 44796634
# ✔ Sixth sense, the → 690849570
# ✔ Almost famous → 46861853
# ✔ Erin brockovich → 44789894
# ✔ O brother, where art thou? → 47146397
# ✔ Sunshine → 46942281
# ✔ American beauty → 42875173
# ✔ Billy elliot → 45847599
# ✔ Dancer in the dark → 46539283
# ✔ Child's play → 234239298
# ✔ Idolmaker, the →
# ✔ Running scared → 49422127
# ✔ Willow → 48509473
# ✔ Drugstore cowboy → 42957808
# ✔ Stanley and Iris → 81362470
# ✔ Fear no evil →
# ✔ How to beat the high cost of living → 903912942
# ✔ Bright lights, big city → 528869410
# ✔ Accidental tourist, the →
# ✔ Stick → 9171061
# ✔ Moonstruck → 46390035
# ✔ Encino man → 46655292
# ✔ Damien → 45111331
# ✔ Last temptation of christ, the →
# ✔ Man, a woman and a bank, a →
# ✔ Triumphs of a man called horse → 11110673
# ✔ After hours → 56116186
# ✔ Quest for fire → 51945616
# ✔ Barbarians at the gate → 47969049
# ✔ Charlie's angels → 46607399
# ✔ Newsies → 48614128
# ✔ Hocus pocus →
# ✔ Frankenstein → 1054996907
# ✔ Commitments, the → 775008785
# ✔ Cast away → 49415426
# ✔ Dark star → 41321066
# ✔ Bulworth → 41021977
# ✔ Fallen → 52008233
# ✔ American pie → 43080735
# ✔ Insider, the →
# ✔ The fugitive → 47151448
# ✔ Dragonheart → 44546998
# ✔ Dragon's teeth →
# ✔ Existenz → 43107293
# ✔ Magnificent seven, the → 909691309
# ✔ Lost highway → 36341116
# ✔ Nuts → 52710497
# ✔ Invisible, the → 193810041
# ✔ Bobby → 77756287
# ✔ Brian's song → 347918
# ✔ Children of men → 81305113
# ✔ Dreamgirls → 85777777
# ✔ Holiday, the →
# ✔ Joy luck club, the → 732792224
# ✔ Rocky balboa → 77553859
# ✔ Prestige, the → 892867986
# ✔ Pursuit of happyness, the → 1136160943
# ✔ Something new → 65212780
# ✔ Topsy-turvy → 764403859
# ✔ Zoom → 76706529
# ✔ Bee season → 62903158
# ✔ Daylight → 70802409
# ✔ Love and a45 →
# ✔ Family guy → 948656738
# ✔ Way fo the gun, the →
# ✔ Love kills aka sid and nancy →
# ✔ Number 23, the →
# ✔ Inside man → 68710175
# ✔ Clueless → 61166414
# ✔ Alexander → 754872148
# ✔ Fantastic 4 → 60826965
# ✔ Iron giant, the →
# ✔ Crank → 74752575
# ✔ Grifters, the →
# ✔ Alice doesn't live here anymore → 56116187
# ✔ The assassination of Jesse James by the coward Robert Ford → 182585178
# ✔ Gone, baby gone → 181596768
# ✔ Hoax, the →
# ✔ Hairspray → 51992171
# ✔ Hott fuzz →
# ✔ No country for old men → 184908513
# ✔ Martian child → 183717096
# ✔ Annie hall → 35318751
# ✔ Crouching tiger, hidden dragon → 51311223
# ✔ Full frontal →
# ✔ Good night, and good luck →
# ✔ Man who wasn't there, the →
# ✔ Postman, the → 1059213206
# ✔ Queen, the → 793224297
# ✔ Sugar and spice → 7082757
# ✔ Syriana → 65212782
# ✔ Tortilla heaven → 244303329
# ✔ Truman show, the → 39383874
# ✔ Truth about charlie, the →
# ✔ Two weeks notice → 51729285
# ✔ Undercover brother → 51099113
# ✔ Unfaithful → 50869031
# ✔ What women want → 46911669
# ✔ Willard → 52710177
# ✔ Woman on top → 50505078
# ✔ X-men → 44259522
# ✔ She's all that → 41875354
# ✔ Queen of the damned → 50396661
# ✔ Deuce Bigalow → 61447170
# ✔ Shaft → 45548181
# ✔ Hamlet → 46795076
# ✔ Gift, the → 826038318
# ✔ Soldier → 40986412
# ✔ Mating habits of the earthbound humans, the →
# ✔ Rules of engagement → 45211673
# ✔ Mothman prophecies, the →
# ✔ Newman's law → 1197988460
# ✔ Street life → 867737456
# ✔ Ace ventura → 33338146
# ✔ The driver → 60643611
# ✔ The fantasticks → 21482670
# ✔ Fearless → 26399024
# ✔ Army of darkness → 436317340
# ✔ Bound → 48705423
# ✔ The nutty professor → 732739814
# ✔ Rapture, the → 29754332
# ✔ Gremlins → 153294501
# ✔ Blind date → 49296746
# ✔ On the waterfront → 48239414
# ✔ Broken arrow → 41262626
# ✔ Star wars → 1198604608
# ✔ Nick of time → 55689342
# ✔ The omen → 2351874
# ✔ Love field → 45800685
# ✔ The day the earth caught fire →
# ✔ Primal fear → 41929643
# ✔ Eraser → 49001385
# ✔ Search → 18988633
# ✔ Waterworld → 40069741
# ✔ Touch → 231623119
# ✔ Mother night → 45260194
# ✔ Chicago hope → 82429346
# ✔ Tremors 2 → 1411251212
# ✔ The last dance → 1019879572
# ✔ Losing isaiah → 55943844
# ✔ Man who wasn't there, the →
# ✔ Secret garden, the → 191077593
# ✔ Brighton beach memoirs → 10017797
# ✔ Body snatchers → 43118134
# ✔ Lost boys ii, the →
# ✔ Reform school girls → 55730911
# ✔ Once around → 57346889
# ✔ New jack city → 752149074
# ✔ Quiet man, the →
# ✔ Over my dead body →
# ✔ Free willy →
# ✔ This boy's life → 68812683
# ✔ Funny lady → 49300456
# ✔ 52 pick-up → 162111765
# ✔ Nine to five → 46823550
# ✔ Hardware → 456578322
# ✔ Play misty for me →
# ✔ Robin hood → 65429180
# ✔ Hudson hawk → 41104697
# ✔ Return to mystic pizza →
# ✔ From dusk till dawn → 33276932
# ✔ Mulholland falls → 56822601
# ✔ Ransom → 54902044
# ✔ Nixon → 49902637
# ✔ A simple plan → 27187407
# ✔ Joe's apartment → 41617155
# ✔ The x-men → 741968294
# ✔ The frighteners → 40770631
# ✔ Flying tigers → 173641072
# ✔ Call northside 777 → 57418741
# ✔ This world, then the fireworks → 1017491863
# ✔ Heat → 1328141116
# ✔ Nine months → 47067405
# ✔ The mummy → 561941652
# ✔ Cure, the →
# ✔ Ambrose chapel → 1519448502
# ✔ Major payne → 46567129
# ✔ Threesome → 48925975
# ✔ Forrest gump → 47981929
# ✔ Casino → 35829711
# ✔ Roger rabbit 2 → 671384254
# ✔ Hoodlum → 40808927
# ✔ Feeling minnesota → 45017081
# ✔ August → 747731656
# ✔ Kull the conqueror → 52169251
# ✔ Getting away with murder → 56208739
# ✔ So help me god →
# ✔ Lightning in a bottle →
# ✔ Grosse pointe blank → 40576596
# ✔ What dreams may come → 52454321
# ✔ Murder one → 57616572
# ✔ Assault on precinct 13 → 57727543
# ✔ A guy named joe → 156284888
# ✔ At close range → 45811832
# ✔ Another thin man → 61137341
# ✔ Apt pupil →
# ✔ Audrey rose → 1582783
# ✔ Bliss → 266973678
# ✔ Foreplay → 62791622
# ✔ The perez family → 51988206
# ✔ The juror → 45440045
# ✔ French kiss → 43392635
# ✔ Mr holland's opus → 42247846
# ✔ Beauty and the beast → 987382561
# ✔ Larger than life → 36982102
# ✔ Sense and sensibility → 42629114
# ✔ Texasville → 15018717
# ✔ Halloween → 171189015
# ✔ Lakeview terrace → 262846285
# ✔ Super bad → 239406980
# ✔ Ninja assassin → 502287066
# ✔ Adventureland → 352926818
# ✔ Everybody's fine →
# ✔ Taking woodstock → 444747871
# ✔ House bunny, the →
# ✔ Feast of love, the →
# ✔ Land of the lost → 427378404
# ✔ Carriers → 476893161
# ✔ Midnight meat train → 301601158
# ✔ Why did i get married? → 68966049
# ✔ Towelhead → 273060928
# ✔ Ugly truth, the →
# ✔ Pride and glory → 277005280
# ✔ Kingdom, the →
# ✔ Saint, the →
# ✔ Apt pupil →
# ✔ Robocop 3 → 56140146
# ✔ Ghost story → 56365688
# ✔ Moving violations → 966291168
# ✔ Addams family values → 29395545
# ✔ True identity → 801264162
# ✔ Iceman → 57533149
# ✔ Paternity → 1434788713
# ✔ Men who stare at goats, the →
# ✔ Music box, the →
# ✔ Spies like us → 527853609
# ✔ Firestarter → 884286667
# ✔ Childs play 2 → 44993708
# ✔ Moonlight mile → 51669665
# ✔ Entity, the →
# ✔ Honey, I shrunk the kids → 50870869
# ✔ Losin' it → 46860386
# ✔ Strange invaders → 48492452
# ✔ Pitch black → 43525146
# ✔ Saving grace → 801274258
# ✔ Flash gordon → 128324343
# ✔ Gandhi → 77523787
# ✔ Osterman weekend, the →
# ✔ Fear city → 70273745
# ✔ Flamingo kid, the →
# ✔ Bird on a wire → 51479767
# ✔ At close range → 45811832
# ✔ Jungle fever → 49223396
# ✔ Outbreak → 39528099
# ✔ Jazz singer, the → 1053547342
# ✔ Best little whorehouse in texas, the → 47734052
# ✔ Lord of the rings, the → 1373884779
# ✔ Deadly blessing → 823763160
# ✔ Ed and his dead mother → 52493283
# ✔ Monkey shines → 50762567
# ✔ Rocky v → 57417677
# ✔ Silverado → 42466416
# ✔ Flight of the navigator → 55205634
# ✔ Gross anatomy → 50994872
# ✔ All the right moves → 49502457
# ✔ My best friend is a vampire → 318358561
# ✔ Overboard → 1040698189
# ✔ Young guns → 52640545
# ✔ Oscar → 52233340
# ✔ Oscar → 52233340
# ✔ Tough guys → 897875
# ✔ Honkytonk man → 6554299
# ✔ Cujo → 1449584406
# ✔ Turk 182! → 405337948
# ✔ Final analysis → 41631716
# ✔ One good cop → 52172235
# ✔ Snake eyes → 40808437
# ✔ Amistad → 42432062
# ✔ Beverly Hills cop → 48885432
# ✔ Born on the 4th of July → 45810791
# ✔ Big sleep, the →
# ✔ Raging bull → 57206235
# ✔ Out of sight → 42723158
# ✔ Jumanji → 43460763
# ✔ Scarface → 53121330
# ✔ Wag the dog → 39692923
# ✔ Some like it hot → 47856715
# ✔ Star trek → 430232998
# ✔ Braveheart → 44909852
# ✔ Postman always rings twice, the →
# ✔ Indiana jones and the temple of doom → 178323331
# ✔ Thief → 868589300
# ✔ Batman forever → 32686788
# ✔ No way out → 47111330
# ✔ Thunderball → 80780106
# ✔ Dracula, prince of darkness → 41448445
# ✔ Leaving las vegas → 34722032
# ✔ Universal soldier → 496024421
# ✔ Hurricane season → 503581926
# ✔ Charlie st cloud → 663145639
# ✔ Life happens → 804911293
# ✔ Bucket list, the →
# ✔ Odd life of timothy green, the →
# ✔ Edge of darkness → 568687179
# ✔ Love happens → 466441469
# ✔ Forgetting Sarah Marshall → 232161733
# ✔ Hannah montana → 320968867
# ✔ Definitely, maybe → 217293725
# ✔ Wanted → 247558252
# ✔ 17 again → 385033187
# ✔ Rachel getting married → 289038632
# ✔ Bottle shock → 275278851
# ✔ Hancock → 246725051
# ✔ A better life → 747046943
# ✔ Tropic thunder → 260574048
# ✔ Campaign, the →
# ✔ Fast & furious → 889896917
# ✔ Magic of belle isle, the →
# ✔ End of watch → 818659161
# ✔ Playing for keeps → 826870875
# ✔ Fun size → 823870447
# ✔ New year's eve → 781643271
# ✔ Citizen, the →
# ✔ Seeking justice → 794506478
# ✔ Canyons, the →
# ✔ He's just not that into you → 317987399
# ✔ Mummy, the → 824608175
# ✔ Funny people → 436307433
# ✔ Green mile, the → 42863050
# ✔ American pop → 39693473
# ✔ 13 → 754964770
# ✔ 13th floor, the →
# ✔ Beaver, the →
# ✔ Breakdown → 40730280
# ✔ F/x 2 → 45066875
# ✔ Go! → 42404750
# ✔ American me → 52132187
# ✔ Primal fear → 41929643
# ✔ Foxfire → 38564560
# ✔ Pushing tin → 54059298
# ✔ Snow angels → 243792603
# ✔ Waking the dead → 45094518
# ✔ Wonderful ice cream suit, the →
# ✔ Days of wine and roses /$cwritten by J P Miller based on teleplay by J P Miller →
# ✔ The legend of hell house /$c written by Richard Matheson based on the novel by Richard Matheson →
# ✔ Andersonville /$cWRITTEN AND PRODUCED BY DAVID W RINTELS →
# ✔ Big easy, the →
# ✔ Stakeout /$cwritten by Jim Kouf →
# ✔ Dead poets society  /$cWRITTEN BY TOM SCHULMAN →
# ✔ Hope floats  /$cWRITTEN BY STEVEN ROGERS →
# ✔ Somewhere in time  / screenplay by richard matheson ; based on his novel " bid time return" →
# ✔ Class  /$cWRITTEN BY JAMES KOUF, JR AND DAVID GREENWALT →
# ✔ Flashback /$c written by David Loughery →
# ✔ Hidden, the →
# ✔ Only you → 41205878
# ✔ The Addams family → 1153553339
# ✔ The 40 year-old virgin → 61851004
# ✔ The devil's advocate → 50752589
# ✔ Live by night → 973888664
# ✔ Equilibrium → 51855848
# ✔ Brick → 69660690
# ✔ 8 mile → 51755406
# ✔ Hidden figures → 974652637
# ✔ The martian → 930929100
# ✔ The red turtle → 978298362
# ✔ A goofy movie → 48540859
# ✔ Everything everywhere all at once → 1320868993
# ✔ Dancing at the blue iguana → 48625163
# ✔ My first mister → 49525504
# ✔ Score, the →
# ✔ Martin and orloff → 62249360
# ✔ Sixth day, the →
# ✔ Evolution → 53176645
# ✔ Prozac nation → 60330241
# ✔ Hollow man → 45657660
# ✔ Leprechan in the hood →
# ✔ Loser → 45617045
# ✔ Heist → 49217149
# ✔ Made → 48393901
# ✔ Looney tunes → 54012513
# ✔ I now pronounce you chuck and larry → 166434023
# ✔ Flawless → 43955642
# ✔ Light it up →
# ✔ Dr t and the women → 875944254
# ✔ Princess diaries, the → 797017373
# ✔ End of days →
# ✔ 28 days → 45041873
# ✔ 102 dalmations → 1267684245
# ✔ Abandon → 51395548
# ✔ All the pretty horses → 46854985
# ✔ Analyze that → 51854431
# ✔ Angel eyes → 48197103
# ✔ Autumn in new york → 45673651
# ✔ Barbershop → 51048855
# ✔ Bicentennial man → 513482
# ✔ Big momma's house → 45546961
# ✔ Big trouble → 50608820
# ✔ Six string samurai → 1005006544
# ✔ Blue streak → 45341536
# ✔ Bring it on → 45944306
# ✔ Bringing out the dead → 43719845
# ✔ Brothers, the →
# ✔ Casanova → 63170380
# ✔ Bulletproof monk → 52548764
# ✔ Clockstoppers → 50283727
# ✔ Confidence → 52710132
# ✔ Crazy/beautiful → 1444572773
# ✔ Driven → 47973691
# ✔ Van wilder → 1032264495
# ✔ Walk on the moon, a →
# ✔ Walk to remember, a →
# ✔ Snow dogs → 49495942
# ✔ World traveler → 51988259
# ✔ Zigzag → 834574072
# ✔ Ed wood → 32239181
# ✔ Sniper → 46850233
# ✔ First strike →
# ✔ Wolf → 949929918
#
# ✅ Finished! Results saved to C:\Users\mchung94\Downloads\710cinscript_oclc_results.xlsx
